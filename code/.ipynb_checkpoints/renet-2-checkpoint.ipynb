# %%
from train import test_renet
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':50,
        'ds_rate':5,
        'renet_d':256,
        'w':32,
        'h':32,
        'c':3,
        'patch_size':2,
        'hidden_num':1,
        'hidden_unit':512,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 512
# verbose: True
# batch_size: 50
# dataset: cifar
# n_epochs: 30
# patch_size: 2
# c: 3
# renet_num: 1
# aug: True
# h: 32
# renet_d: 256
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 1, learning_rate 0.100000 minibatch 900/900, validation error 56.440000 %
#      epoch 1, minibatch 900/900, test error of best model 55.940000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# ...

# %%
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':500,
        'renet_num':1,
        'adapt':False
}
test_renet(**param)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-386d419960cd> in <module>()
#      15         'adapt':False
#      16 }
# ---> 17 test_renet(**param)
#
# /home/ubuntu/extern/nn_proj/src/train.pyc in test_renet(**kwargs)
#     152     param_diff = set(kwargs.keys()) - set(param.keys())
#     153     if param_diff:
# --> 154         raise KeyError("invalid arguments:" + str(tuple(param_diff)))
#     155     param.update(kwargs)
#     156     if param['verbose']:
#
# KeyError: "invalid arguments:('adapt',)"
