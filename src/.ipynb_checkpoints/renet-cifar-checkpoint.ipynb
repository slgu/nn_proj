# %%
from train import test_renet
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':50,
        'ds_rate':5,
        'renet_d':256,
        'w':32,
        'h':32,
        'c':3,
        'patch_size':2,
        'hidden_num':1,
        'hidden_unit':512,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 512
# verbose: True
# batch_size: 50
# dataset: cifar
# n_epochs: 30
# patch_size: 2
# c: 3
# renet_num: 1
# aug: True
# h: 32
# renet_d: 256
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# epoch 1, learning_rate 0.100000 minibatch 900/900, validation error 46.440000 %
#      epoch 1, minibatch 900/900, test error of best model 45.940000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# epoch 2, learning_rate 0.100000 minibatch 900/900, validation error 43.820000 %
#      epoch 2, minibatch 900/900, test error of best model 44.150000 %
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# epoch 3, learning_rate 0.100000 minibatch 900/900, validation error 40.620000 %
#      epoch 3, minibatch 900/900, test error of best model 40.760000 %
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# training @ iter =  3300
# training @ iter =  3400
# training @ iter =  3500
# epoch 4, learning_rate 0.100000 minibatch 900/900, validation error 37.740000 %
#      epoch 4, minibatch 900/900, test error of best model 38.130000 %
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# training @ iter =  3900
# training @ iter =  4000
# training @ iter =  4100
# training @ iter =  4200
# training @ iter =  4300
# training @ iter =  4400
# epoch 5, learning_rate 0.100000 minibatch 900/900, validation error 36.080000 %
#      epoch 5, minibatch 900/900, test error of best model 37.010000 %
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# training @ iter =  4800
# training @ iter =  4900
# training @ iter =  5000
# training @ iter =  5100
# training @ iter =  5200
# training @ iter =  5300
# epoch 6, learning_rate 0.100000 minibatch 900/900, validation error 32.680000 %
#      epoch 6, minibatch 900/900, test error of best model 33.710000 %
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# training @ iter =  5700
# training @ iter =  5800
# training @ iter =  5900
# training @ iter =  6000
# training @ iter =  6100
# training @ iter =  6200
# epoch 7, learning_rate 0.100000 minibatch 900/900, validation error 31.700000 %
#      epoch 7, minibatch 900/900, test error of best model 32.250000 %
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# training @ iter =  6600
# training @ iter =  6700
# training @ iter =  6800
# training @ iter =  6900
# training @ iter =  7000
# training @ iter =  7100
# epoch 8, learning_rate 0.100000 minibatch 900/900, validation error 32.040000 %
# training @ iter =  7200
# training @ iter =  7300
# training @ iter =  7400
# training @ iter =  7500
# training @ iter =  7600
# training @ iter =  7700
# training @ iter =  7800
# training @ iter =  7900
# training @ iter =  8000
# epoch 9, learning_rate 0.086957 minibatch 900/900, validation error 29.260000 %
#      epoch 9, minibatch 900/900, test error of best model 29.630000 %
# training @ iter =  8100
# training @ iter =  8200
# training @ iter =  8300
# training @ iter =  8400
# training @ iter =  8500
# training @ iter =  8600
# training @ iter =  8700
# training @ iter =  8800
# training @ iter =  8900
# epoch 10, learning_rate 0.086957 minibatch 900/900, validation error 27.700000 %
#      epoch 10, minibatch 900/900, test error of best model 27.960000 %
# training @ iter =  9000
# training @ iter =  9100
# training @ iter =  9200
# training @ iter =  9300
# training @ iter =  9400
# training @ iter =  9500
# training @ iter =  9600
# training @ iter =  9700
# training @ iter =  9800
# epoch 11, learning_rate 0.086957 minibatch 900/900, validation error 27.240000 %
#      epoch 11, minibatch 900/900, test error of best model 28.270000 %
# training @ iter =  9900
# training @ iter =  10000
# training @ iter =  10100
# training @ iter =  10200
# training @ iter =  10300
# training @ iter =  10400
# training @ iter =  10500
# training @ iter =  10600
# training @ iter =  10700
# epoch 12, learning_rate 0.086957 minibatch 900/900, validation error 27.580000 %
# training @ iter =  10800
# training @ iter =  10900
# training @ iter =  11000
# training @ iter =  11100
# training @ iter =  11200
# training @ iter =  11300
# training @ iter =  11400
# training @ iter =  11500
# training @ iter =  11600
# epoch 13, learning_rate 0.076923 minibatch 900/900, validation error 26.460000 %
#      epoch 13, minibatch 900/900, test error of best model 26.860000 %
# training @ iter =  11700
# training @ iter =  11800
# training @ iter =  11900
# training @ iter =  12000
# training @ iter =  12100
# training @ iter =  12200
# training @ iter =  12300
# training @ iter =  12400
# training @ iter =  12500
# epoch 14, learning_rate 0.076923 minibatch 900/900, validation error 25.680000 %
#      epoch 14, minibatch 900/900, test error of best model 26.280000 %
# training @ iter =  12600
# training @ iter =  12700
# training @ iter =  12800
# training @ iter =  12900
# training @ iter =  13000
# training @ iter =  13100
# training @ iter =  13200
# training @ iter =  13300
# training @ iter =  13400
# epoch 15, learning_rate 0.076923 minibatch 900/900, validation error 25.860000 %
# training @ iter =  13500
# training @ iter =  13600
# training @ iter =  13700
# training @ iter =  13800
# training @ iter =  13900
# training @ iter =  14000
# training @ iter =  14100
# training @ iter =  14200
# training @ iter =  14300
# epoch 16, learning_rate 0.068966 minibatch 900/900, validation error 23.860000 %
#      epoch 16, minibatch 900/900, test error of best model 25.290000 %
# training @ iter =  14400
# training @ iter =  14500
# training @ iter =  14600
# training @ iter =  14700
# training @ iter =  14800
# training @ iter =  14900
# training @ iter =  15000
# training @ iter =  15100
# training @ iter =  15200
# epoch 17, learning_rate 0.068966 minibatch 900/900, validation error 23.440000 %
#      epoch 17, minibatch 900/900, test error of best model 24.710000 %
# training @ iter =  15300
# training @ iter =  15400
# training @ iter =  15500
# training @ iter =  15600
# training @ iter =  15700
# training @ iter =  15800
# training @ iter =  15900
# training @ iter =  16000
# training @ iter =  16100
# epoch 18, learning_rate 0.068966 minibatch 900/900, validation error 23.100000 %
#      epoch 18, minibatch 900/900, test error of best model 24.030000 %
# training @ iter =  16200
# training @ iter =  16300
# training @ iter =  16400
# training @ iter =  16500
# training @ iter =  16600
# training @ iter =  16700
# training @ iter =  16800
# training @ iter =  16900
# training @ iter =  17000
# epoch 19, learning_rate 0.068966 minibatch 900/900, validation error 22.000000 %
#      epoch 19, minibatch 900/900, test error of best model 23.110000 %
# training @ iter =  17100
# training @ iter =  17200
# training @ iter =  17300
# training @ iter =  17400
# training @ iter =  17500
# training @ iter =  17600
# training @ iter =  17700
# training @ iter =  17800
# training @ iter =  17900
# epoch 20, learning_rate 0.068966 minibatch 900/900, validation error 21.860000 %
#      epoch 20, minibatch 900/900, test error of best model 22.590000 %
# training @ iter =  18000
# training @ iter =  18100
# training @ iter =  18200
# training @ iter =  18300
# training @ iter =  18400
# training @ iter =  18500
# training @ iter =  18600
# training @ iter =  18700
# training @ iter =  18800
# epoch 21, learning_rate 0.062500 minibatch 900/900, validation error 21.640000 %
#      epoch 21, minibatch 900/900, test error of best model 22.490000 %
# training @ iter =  18900
# training @ iter =  19000
# training @ iter =  19100
# training @ iter =  19200
# training @ iter =  19300
# training @ iter =  19400
# training @ iter =  19500
# training @ iter =  19600
# training @ iter =  19700
# epoch 22, learning_rate 0.062500 minibatch 900/900, validation error 21.780000 %
# training @ iter =  19800
# training @ iter =  19900
# training @ iter =  20000
# training @ iter =  20100
# training @ iter =  20200
# training @ iter =  20300
# training @ iter =  20400
# training @ iter =  20500
# training @ iter =  20600
# epoch 23, learning_rate 0.057143 minibatch 900/900, validation error 21.560000 %
#      epoch 23, minibatch 900/900, test error of best model 22.390000 %
# training @ iter =  20700
# training @ iter =  20800
# training @ iter =  20900
# training @ iter =  21000
# training @ iter =  21100
# training @ iter =  21200
# training @ iter =  21300
# training @ iter =  21400
# training @ iter =  21500
# epoch 24, learning_rate 0.052632 minibatch 900/900, validation error 21.220000 %
#      epoch 24, minibatch 900/900, test error of best model 22.310000 %
# training @ iter =  21600
# training @ iter =  21700
# training @ iter =  21800
# training @ iter =  21900
# training @ iter =  22000
# training @ iter =  22100
# training @ iter =  22200
# training @ iter =  22300
# training @ iter =  22400
# epoch 25, learning_rate 0.052632 minibatch 900/900, validation error 21.180000 %
#      epoch 25, minibatch 900/900, test error of best model 22.070000 %
# training @ iter =  22500
# training @ iter =  22600
# training @ iter =  22700
# training @ iter =  22800
# training @ iter =  22900
# training @ iter =  23000
# training @ iter =  23100
# training @ iter =  23200
# training @ iter =  23300
# epoch 26, learning_rate 0.048780 minibatch 900/900, validation error 21.140000 %
#      epoch 26, minibatch 900/900, test error of best model 21.960000 %
# training @ iter =  23400
# training @ iter =  23500
# training @ iter =  23600
# training @ iter =  23700
# training @ iter =  23800
# training @ iter =  23900
# training @ iter =  24000
# training @ iter =  24100
# training @ iter =  24200
# epoch 27, learning_rate 0.045455 minibatch 900/900, validation error 21.140000 %
# training @ iter =  24300
# training @ iter =  24400
# training @ iter =  24500
# training @ iter =  24600
# training @ iter =  24700
# training @ iter =  24800
# training @ iter =  24900
# training @ iter =  25000
# training @ iter =  25100
# epoch 28, learning_rate 0.042553 minibatch 900/900, validation error 21.100000 %
#      epoch 28, minibatch 900/900, test error of best model 21.900000 %
# training @ iter =  25200
# training @ iter =  25300
# training @ iter =  25400
# training @ iter =  25500
# training @ iter =  25600
# training @ iter =  25700
# training @ iter =  25800
# training @ iter =  25900
# training @ iter =  26000
# epoch 29, learning_rate 0.040000 minibatch 900/900, validation error 21.120000 %
# training @ iter =  26100
# training @ iter =  26200
# training @ iter =  26300
# training @ iter =  26400
# training @ iter =  26500
# training @ iter =  26600
# training @ iter =  26700
# training @ iter =  26800
# training @ iter =  26900
# epoch 30, learning_rate 0.037736 minibatch 900/900, validation error 21.100000 %
# Optimization complete.
# Best validation score of 21.100000 % obtained at iteration 25200, with test performance 21.900000 %
# The training process for function test_renet ran for 244.44m

# %%
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':500,
        'renet_num':1,
        'adapt':False
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 500
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: True
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# adapt: False
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 51.400000 %
#      epoch 1, minibatch 225/225, test error of best model 50.040000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 46.340000 %
#      epoch 2, minibatch 225/225, test error of best model 46.520000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 44.620000 %
#      epoch 3, minibatch 225/225, test error of best model 43.950000 %
# training @ iter =  700
# training @ iter =  800
# epoch 4, learning_rate 0.100000 minibatch 225/225, validation error 42.520000 %
#      epoch 4, minibatch 225/225, test error of best model 42.060000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# epoch 5, learning_rate 0.100000 minibatch 225/225, validation error 40.820000 %
#      epoch 5, minibatch 225/225, test error of best model 40.400000 %
# training @ iter =  1200
# training @ iter =  1300
# epoch 6, learning_rate 0.100000 minibatch 225/225, validation error 39.440000 %
#      epoch 6, minibatch 225/225, test error of best model 38.860000 %
# training @ iter =  1400
# training @ iter =  1500
# epoch 7, learning_rate 0.100000 minibatch 225/225, validation error 37.780000 %
#      epoch 7, minibatch 225/225, test error of best model 37.600000 %
# training @ iter =  1600
# training @ iter =  1700
# epoch 8, learning_rate 0.100000 minibatch 225/225, validation error 36.440000 %
#      epoch 8, minibatch 225/225, test error of best model 36.500000 %
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# epoch 9, learning_rate 0.100000 minibatch 225/225, validation error 35.680000 %
#      epoch 9, minibatch 225/225, test error of best model 35.270000 %
# training @ iter =  2100
# training @ iter =  2200
# epoch 10, learning_rate 0.100000 minibatch 225/225, validation error 34.540000 %
#      epoch 10, minibatch 225/225, test error of best model 34.520000 %
# training @ iter =  2300
# training @ iter =  2400
# epoch 11, learning_rate 0.100000 minibatch 225/225, validation error 33.500000 %
#      epoch 11, minibatch 225/225, test error of best model 33.610000 %
# training @ iter =  2500
# training @ iter =  2600
# epoch 12, learning_rate 0.100000 minibatch 225/225, validation error 32.760000 %
#      epoch 12, minibatch 225/225, test error of best model 33.310000 %
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# epoch 13, learning_rate 0.100000 minibatch 225/225, validation error 32.100000 %
#      epoch 13, minibatch 225/225, test error of best model 32.670000 %
# training @ iter =  3000
# training @ iter =  3100
# epoch 14, learning_rate 0.100000 minibatch 225/225, validation error 31.520000 %
#      epoch 14, minibatch 225/225, test error of best model 32.000000 %
# training @ iter =  3200
# training @ iter =  3300
# epoch 15, learning_rate 0.100000 minibatch 225/225, validation error 31.120000 %
#      epoch 15, minibatch 225/225, test error of best model 31.490000 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 16, learning_rate 0.100000 minibatch 225/225, validation error 30.900000 %
#      epoch 16, minibatch 225/225, test error of best model 31.400000 %
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# epoch 17, learning_rate 0.100000 minibatch 225/225, validation error 30.520000 %
#      epoch 17, minibatch 225/225, test error of best model 31.240000 %
# training @ iter =  3900
# training @ iter =  4000
# epoch 18, learning_rate 0.100000 minibatch 225/225, validation error 30.000000 %
#      epoch 18, minibatch 225/225, test error of best model 30.960000 %
# training @ iter =  4100
# training @ iter =  4200
# epoch 19, learning_rate 0.100000 minibatch 225/225, validation error 29.600000 %
#      epoch 19, minibatch 225/225, test error of best model 30.890000 %
# training @ iter =  4300
# training @ iter =  4400
# epoch 20, learning_rate 0.100000 minibatch 225/225, validation error 29.420000 %
#      epoch 20, minibatch 225/225, test error of best model 30.660000 %
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# epoch 21, learning_rate 0.100000 minibatch 225/225, validation error 29.140000 %
#      epoch 21, minibatch 225/225, test error of best model 30.520000 %
# training @ iter =  4800
# training @ iter =  4900
# epoch 22, learning_rate 0.100000 minibatch 225/225, validation error 29.440000 %
# training @ iter =  5000
# training @ iter =  5100
# epoch 23, learning_rate 0.100000 minibatch 225/225, validation error 29.540000 %
# training @ iter =  5200
# training @ iter =  5300
# epoch 24, learning_rate 0.100000 minibatch 225/225, validation error 29.280000 %
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# epoch 25, learning_rate 0.100000 minibatch 225/225, validation error 29.200000 %
# training @ iter =  5700
# training @ iter =  5800
# epoch 26, learning_rate 0.100000 minibatch 225/225, validation error 29.320000 %
# training @ iter =  5900
# training @ iter =  6000
# epoch 27, learning_rate 0.100000 minibatch 225/225, validation error 29.600000 %
# training @ iter =  6100
# training @ iter =  6200
# epoch 28, learning_rate 0.100000 minibatch 225/225, validation error 29.320000 %
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# epoch 29, learning_rate 0.100000 minibatch 225/225, validation error 28.980000 %
#      epoch 29, minibatch 225/225, test error of best model 30.110000 %
# training @ iter =  6600
# training @ iter =  6700
# epoch 30, learning_rate 0.100000 minibatch 225/225, validation error 28.600000 %
#      epoch 30, minibatch 225/225, test error of best model 29.970000 %
# Optimization complete.
# Best validation score of 28.600000 % obtained at iteration 6750, with test performance 29.970000 %
# The training process for function test_renet ran for 18.41m

# %%
# With augmentation
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':500,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 500
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: True
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 51.780000 %
#      epoch 1, minibatch 225/225, test error of best model 50.840000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 47.560000 %
#      epoch 2, minibatch 225/225, test error of best model 47.150000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 44.820000 %
#      epoch 3, minibatch 225/225, test error of best model 44.140000 %
# training @ iter =  700
# training @ iter =  800
# epoch 4, learning_rate 0.100000 minibatch 225/225, validation error 42.780000 %
#      epoch 4, minibatch 225/225, test error of best model 42.130000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# epoch 5, learning_rate 0.100000 minibatch 225/225, validation error 41.060000 %
#      epoch 5, minibatch 225/225, test error of best model 40.410000 %
# training @ iter =  1200
# training @ iter =  1300
# epoch 6, learning_rate 0.100000 minibatch 225/225, validation error 39.280000 %
#      epoch 6, minibatch 225/225, test error of best model 38.940000 %
# training @ iter =  1400
# training @ iter =  1500
# epoch 7, learning_rate 0.100000 minibatch 225/225, validation error 38.020000 %
#      epoch 7, minibatch 225/225, test error of best model 37.680000 %
# training @ iter =  1600
# training @ iter =  1700
# epoch 8, learning_rate 0.100000 minibatch 225/225, validation error 36.800000 %
#      epoch 8, minibatch 225/225, test error of best model 36.560000 %
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# epoch 9, learning_rate 0.100000 minibatch 225/225, validation error 35.560000 %
#      epoch 9, minibatch 225/225, test error of best model 35.740000 %
# training @ iter =  2100
# training @ iter =  2200
# epoch 10, learning_rate 0.100000 minibatch 225/225, validation error 34.380000 %
#      epoch 10, minibatch 225/225, test error of best model 34.920000 %
# training @ iter =  2300
# training @ iter =  2400
# epoch 11, learning_rate 0.100000 minibatch 225/225, validation error 33.760000 %
#      epoch 11, minibatch 225/225, test error of best model 34.210000 %
# training @ iter =  2500
# training @ iter =  2600
# epoch 12, learning_rate 0.100000 minibatch 225/225, validation error 32.940000 %
#      epoch 12, minibatch 225/225, test error of best model 33.550000 %
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# epoch 13, learning_rate 0.100000 minibatch 225/225, validation error 32.100000 %
#      epoch 13, minibatch 225/225, test error of best model 33.260000 %
# training @ iter =  3000
# training @ iter =  3100
# epoch 14, learning_rate 0.100000 minibatch 225/225, validation error 31.640000 %
#      epoch 14, minibatch 225/225, test error of best model 32.820000 %
# training @ iter =  3200
# training @ iter =  3300
# epoch 15, learning_rate 0.100000 minibatch 225/225, validation error 31.200000 %
#      epoch 15, minibatch 225/225, test error of best model 32.160000 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 16, learning_rate 0.100000 minibatch 225/225, validation error 30.880000 %
#      epoch 16, minibatch 225/225, test error of best model 31.510000 %
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# epoch 17, learning_rate 0.100000 minibatch 225/225, validation error 30.600000 %
#      epoch 17, minibatch 225/225, test error of best model 31.260000 %
# training @ iter =  3900
# training @ iter =  4000
# epoch 18, learning_rate 0.100000 minibatch 225/225, validation error 30.540000 %
#      epoch 18, minibatch 225/225, test error of best model 30.970000 %
# training @ iter =  4100
# training @ iter =  4200
# epoch 19, learning_rate 0.090909 minibatch 225/225, validation error 29.880000 %
#      epoch 19, minibatch 225/225, test error of best model 30.770000 %
# training @ iter =  4300
# training @ iter =  4400
# epoch 20, learning_rate 0.090909 minibatch 225/225, validation error 29.720000 %
#      epoch 20, minibatch 225/225, test error of best model 30.700000 %
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# epoch 21, learning_rate 0.083333 minibatch 225/225, validation error 29.440000 %
#      epoch 21, minibatch 225/225, test error of best model 30.590000 %
# training @ iter =  4800
# training @ iter =  4900
# epoch 22, learning_rate 0.083333 minibatch 225/225, validation error 29.440000 %
# training @ iter =  5000
# training @ iter =  5100
# epoch 23, learning_rate 0.076923 minibatch 225/225, validation error 29.480000 %
# training @ iter =  5200
# training @ iter =  5300
# epoch 24, learning_rate 0.071429 minibatch 225/225, validation error 29.520000 %
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# epoch 25, learning_rate 0.066667 minibatch 225/225, validation error 29.620000 %
# training @ iter =  5700
# training @ iter =  5800
# epoch 26, learning_rate 0.062500 minibatch 225/225, validation error 29.340000 %
#      epoch 26, minibatch 225/225, test error of best model 29.880000 %
# training @ iter =  5900
# training @ iter =  6000
# epoch 27, learning_rate 0.058824 minibatch 225/225, validation error 29.060000 %
#      epoch 27, minibatch 225/225, test error of best model 29.850000 %
# training @ iter =  6100
# training @ iter =  6200
# epoch 28, learning_rate 0.058824 minibatch 225/225, validation error 28.920000 %
#      epoch 28, minibatch 225/225, test error of best model 29.730000 %
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# epoch 29, learning_rate 0.055556 minibatch 225/225, validation error 28.940000 %
# training @ iter =  6600
# training @ iter =  6700
# epoch 30, learning_rate 0.052632 minibatch 225/225, validation error 28.900000 %
#      epoch 30, minibatch 225/225, test error of best model 29.410000 %
# Optimization complete.
# Best validation score of 28.900000 % obtained at iteration 6750, with test performance 29.410000 %
# The training process for function test_renet ran for 17.58m

# %%
# Without augmentation
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'aug': False,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':500,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 500
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: False
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 51.320000 %
#      epoch 1, minibatch 225/225, test error of best model 50.920000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 46.980000 %
#      epoch 2, minibatch 225/225, test error of best model 46.710000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 44.140000 %
#      epoch 3, minibatch 225/225, test error of best model 43.630000 %
# training @ iter =  700
# training @ iter =  800
# epoch 4, learning_rate 0.100000 minibatch 225/225, validation error 42.140000 %
#      epoch 4, minibatch 225/225, test error of best model 41.440000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# epoch 5, learning_rate 0.100000 minibatch 225/225, validation error 39.960000 %
#      epoch 5, minibatch 225/225, test error of best model 39.620000 %
# training @ iter =  1200
# training @ iter =  1300
# epoch 6, learning_rate 0.100000 minibatch 225/225, validation error 38.540000 %
#      epoch 6, minibatch 225/225, test error of best model 37.860000 %
# training @ iter =  1400
# training @ iter =  1500
# epoch 7, learning_rate 0.100000 minibatch 225/225, validation error 36.600000 %
#      epoch 7, minibatch 225/225, test error of best model 36.300000 %
# training @ iter =  1600
# training @ iter =  1700
# epoch 8, learning_rate 0.100000 minibatch 225/225, validation error 35.280000 %
#      epoch 8, minibatch 225/225, test error of best model 34.950000 %
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# epoch 9, learning_rate 0.100000 minibatch 225/225, validation error 33.720000 %
#      epoch 9, minibatch 225/225, test error of best model 34.120000 %
# training @ iter =  2100
# training @ iter =  2200
# epoch 10, learning_rate 0.100000 minibatch 225/225, validation error 32.800000 %
#      epoch 10, minibatch 225/225, test error of best model 33.470000 %
# training @ iter =  2300
# training @ iter =  2400
# epoch 11, learning_rate 0.100000 minibatch 225/225, validation error 32.220000 %
#      epoch 11, minibatch 225/225, test error of best model 32.990000 %
# training @ iter =  2500
# training @ iter =  2600
# epoch 12, learning_rate 0.100000 minibatch 225/225, validation error 31.500000 %
#      epoch 12, minibatch 225/225, test error of best model 32.440000 %
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# epoch 13, learning_rate 0.100000 minibatch 225/225, validation error 30.680000 %
#      epoch 13, minibatch 225/225, test error of best model 32.060000 %
# training @ iter =  3000
# training @ iter =  3100
# epoch 14, learning_rate 0.100000 minibatch 225/225, validation error 30.380000 %
#      epoch 14, minibatch 225/225, test error of best model 31.670000 %
# training @ iter =  3200
# training @ iter =  3300
# epoch 15, learning_rate 0.100000 minibatch 225/225, validation error 29.840000 %
#      epoch 15, minibatch 225/225, test error of best model 31.150000 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 16, learning_rate 0.100000 minibatch 225/225, validation error 29.380000 %
#      epoch 16, minibatch 225/225, test error of best model 30.760000 %
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# epoch 17, learning_rate 0.100000 minibatch 225/225, validation error 28.800000 %
#      epoch 17, minibatch 225/225, test error of best model 30.430000 %
# training @ iter =  3900
# training @ iter =  4000
# epoch 18, learning_rate 0.100000 minibatch 225/225, validation error 28.760000 %
#      epoch 18, minibatch 225/225, test error of best model 30.040000 %
# training @ iter =  4100
# training @ iter =  4200
# epoch 19, learning_rate 0.090909 minibatch 225/225, validation error 28.160000 %
#      epoch 19, minibatch 225/225, test error of best model 29.490000 %
# training @ iter =  4300
# training @ iter =  4400
# epoch 20, learning_rate 0.090909 minibatch 225/225, validation error 27.800000 %
#      epoch 20, minibatch 225/225, test error of best model 29.370000 %
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# epoch 21, learning_rate 0.090909 minibatch 225/225, validation error 27.860000 %
# training @ iter =  4800
# training @ iter =  4900
# epoch 22, learning_rate 0.083333 minibatch 225/225, validation error 27.280000 %
#      epoch 22, minibatch 225/225, test error of best model 28.960000 %
# training @ iter =  5000
# training @ iter =  5100
# epoch 23, learning_rate 0.083333 minibatch 225/225, validation error 27.060000 %
#      epoch 23, minibatch 225/225, test error of best model 28.800000 %
# training @ iter =  5200
# training @ iter =  5300
# epoch 24, learning_rate 0.083333 minibatch 225/225, validation error 27.300000 %
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# epoch 25, learning_rate 0.076923 minibatch 225/225, validation error 27.200000 %
# training @ iter =  5700
# training @ iter =  5800
# epoch 26, learning_rate 0.071429 minibatch 225/225, validation error 26.940000 %
#      epoch 26, minibatch 225/225, test error of best model 28.900000 %
# training @ iter =  5900
# training @ iter =  6000
# epoch 27, learning_rate 0.066667 minibatch 225/225, validation error 26.700000 %
#      epoch 27, minibatch 225/225, test error of best model 28.650000 %
# training @ iter =  6100
# training @ iter =  6200
# epoch 28, learning_rate 0.066667 minibatch 225/225, validation error 26.760000 %
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# epoch 29, learning_rate 0.062500 minibatch 225/225, validation error 26.800000 %
# training @ iter =  6600
# training @ iter =  6700
# epoch 30, learning_rate 0.058824 minibatch 225/225, validation error 26.600000 %
#      epoch 30, minibatch 225/225, test error of best model 28.210000 %
# Optimization complete.
# Best validation score of 26.600000 % obtained at iteration 6750, with test performance 28.210000 %
# The training process for function test_renet ran for 17.68m

# %%
# less hidden state of renet
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':40,
        'w':32,
        'h':32,
        'c':3,
        'aug': False,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':500,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 500
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: False
# h: 32
# renet_d: 40
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 53.560000 %
#      epoch 1, minibatch 225/225, test error of best model 52.220000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 48.880000 %
#      epoch 2, minibatch 225/225, test error of best model 48.030000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 46.040000 %
#      epoch 3, minibatch 225/225, test error of best model 45.960000 %
# training @ iter =  700
# training @ iter =  800
# epoch 4, learning_rate 0.100000 minibatch 225/225, validation error 43.800000 %
#      epoch 4, minibatch 225/225, test error of best model 43.510000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# epoch 5, learning_rate 0.100000 minibatch 225/225, validation error 41.720000 %
#      epoch 5, minibatch 225/225, test error of best model 41.480000 %
# training @ iter =  1200
# training @ iter =  1300
# epoch 6, learning_rate 0.100000 minibatch 225/225, validation error 40.020000 %
#      epoch 6, minibatch 225/225, test error of best model 39.700000 %
# training @ iter =  1400
# training @ iter =  1500
# epoch 7, learning_rate 0.100000 minibatch 225/225, validation error 38.220000 %
#      epoch 7, minibatch 225/225, test error of best model 38.120000 %
# training @ iter =  1600
# training @ iter =  1700
# epoch 8, learning_rate 0.100000 minibatch 225/225, validation error 36.840000 %
#      epoch 8, minibatch 225/225, test error of best model 37.140000 %
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# epoch 9, learning_rate 0.100000 minibatch 225/225, validation error 35.520000 %
#      epoch 9, minibatch 225/225, test error of best model 36.020000 %
# training @ iter =  2100
# training @ iter =  2200
# epoch 10, learning_rate 0.100000 minibatch 225/225, validation error 34.540000 %
#      epoch 10, minibatch 225/225, test error of best model 35.320000 %
# training @ iter =  2300
# training @ iter =  2400
# epoch 11, learning_rate 0.100000 minibatch 225/225, validation error 33.280000 %
#      epoch 11, minibatch 225/225, test error of best model 34.160000 %
# training @ iter =  2500
# training @ iter =  2600
# epoch 12, learning_rate 0.100000 minibatch 225/225, validation error 32.320000 %
#      epoch 12, minibatch 225/225, test error of best model 33.280000 %
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# epoch 13, learning_rate 0.100000 minibatch 225/225, validation error 31.560000 %
#      epoch 13, minibatch 225/225, test error of best model 32.520000 %
# training @ iter =  3000
# training @ iter =  3100
# epoch 14, learning_rate 0.100000 minibatch 225/225, validation error 30.940000 %
#      epoch 14, minibatch 225/225, test error of best model 32.030000 %
# training @ iter =  3200
# training @ iter =  3300
# epoch 15, learning_rate 0.100000 minibatch 225/225, validation error 30.160000 %
#      epoch 15, minibatch 225/225, test error of best model 31.620000 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 16, learning_rate 0.100000 minibatch 225/225, validation error 29.620000 %
#      epoch 16, minibatch 225/225, test error of best model 31.200000 %
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# epoch 17, learning_rate 0.100000 minibatch 225/225, validation error 28.940000 %
#      epoch 17, minibatch 225/225, test error of best model 30.660000 %
# training @ iter =  3900
# training @ iter =  4000
# epoch 18, learning_rate 0.100000 minibatch 225/225, validation error 28.680000 %
#      epoch 18, minibatch 225/225, test error of best model 30.110000 %
# training @ iter =  4100
# training @ iter =  4200
# epoch 19, learning_rate 0.100000 minibatch 225/225, validation error 28.500000 %
#      epoch 19, minibatch 225/225, test error of best model 29.740000 %
# training @ iter =  4300
# training @ iter =  4400
# epoch 20, learning_rate 0.090909 minibatch 225/225, validation error 27.940000 %
#      epoch 20, minibatch 225/225, test error of best model 29.680000 %
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# epoch 21, learning_rate 0.090909 minibatch 225/225, validation error 27.700000 %
#      epoch 21, minibatch 225/225, test error of best model 29.420000 %
# training @ iter =  4800
# training @ iter =  4900
# epoch 22, learning_rate 0.090909 minibatch 225/225, validation error 27.680000 %
#      epoch 22, minibatch 225/225, test error of best model 29.070000 %
# training @ iter =  5000
# training @ iter =  5100
# epoch 23, learning_rate 0.083333 minibatch 225/225, validation error 27.420000 %
#      epoch 23, minibatch 225/225, test error of best model 28.840000 %
# training @ iter =  5200
# training @ iter =  5300
# epoch 24, learning_rate 0.083333 minibatch 225/225, validation error 27.340000 %
#      epoch 24, minibatch 225/225, test error of best model 28.870000 %
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# epoch 25, learning_rate 0.076923 minibatch 225/225, validation error 27.340000 %
# training @ iter =  5700
# training @ iter =  5800
# epoch 26, learning_rate 0.071429 minibatch 225/225, validation error 27.460000 %
# training @ iter =  5900
# training @ iter =  6000
# epoch 27, learning_rate 0.066667 minibatch 225/225, validation error 27.280000 %
#      epoch 27, minibatch 225/225, test error of best model 28.700000 %
# training @ iter =  6100
# training @ iter =  6200
# epoch 28, learning_rate 0.062500 minibatch 225/225, validation error 27.040000 %
#      epoch 28, minibatch 225/225, test error of best model 28.630000 %
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# epoch 29, learning_rate 0.062500 minibatch 225/225, validation error 26.860000 %
#      epoch 29, minibatch 225/225, test error of best model 28.670000 %
# training @ iter =  6600
# training @ iter =  6700
# epoch 30, learning_rate 0.058824 minibatch 225/225, validation error 26.880000 %
# Optimization complete.
# Best validation score of 26.860000 % obtained at iteration 6525, with test performance 28.670000 %
# The training process for function test_renet ran for 12.49m

# %%
# less hidden unit of mlp
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'aug': False,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':200,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 200
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: False
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 51.980000 %
#      epoch 1, minibatch 225/225, test error of best model 51.290000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 46.880000 %
#      epoch 2, minibatch 225/225, test error of best model 46.540000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 43.840000 %
#      epoch 3, minibatch 225/225, test error of best model 42.890000 %
# training @ iter =  700
# training @ iter =  800
# epoch 4, learning_rate 0.100000 minibatch 225/225, validation error 40.780000 %
#      epoch 4, minibatch 225/225, test error of best model 40.320000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# epoch 5, learning_rate 0.100000 minibatch 225/225, validation error 38.540000 %
#      epoch 5, minibatch 225/225, test error of best model 38.170000 %
# training @ iter =  1200
# training @ iter =  1300
# epoch 6, learning_rate 0.100000 minibatch 225/225, validation error 36.460000 %
#      epoch 6, minibatch 225/225, test error of best model 36.740000 %
# training @ iter =  1400
# training @ iter =  1500
# epoch 7, learning_rate 0.100000 minibatch 225/225, validation error 35.400000 %
#      epoch 7, minibatch 225/225, test error of best model 35.410000 %
# training @ iter =  1600
# training @ iter =  1700
# epoch 8, learning_rate 0.100000 minibatch 225/225, validation error 33.980000 %
#      epoch 8, minibatch 225/225, test error of best model 34.230000 %
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# epoch 9, learning_rate 0.100000 minibatch 225/225, validation error 32.780000 %
#      epoch 9, minibatch 225/225, test error of best model 33.440000 %
# training @ iter =  2100
# training @ iter =  2200
# epoch 10, learning_rate 0.100000 minibatch 225/225, validation error 31.740000 %
#      epoch 10, minibatch 225/225, test error of best model 32.810000 %
# training @ iter =  2300
# training @ iter =  2400
# epoch 11, learning_rate 0.100000 minibatch 225/225, validation error 31.240000 %
#      epoch 11, minibatch 225/225, test error of best model 32.360000 %
# training @ iter =  2500
# training @ iter =  2600
# epoch 12, learning_rate 0.100000 minibatch 225/225, validation error 30.420000 %
#      epoch 12, minibatch 225/225, test error of best model 32.020000 %
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# epoch 13, learning_rate 0.100000 minibatch 225/225, validation error 29.980000 %
#      epoch 13, minibatch 225/225, test error of best model 31.710000 %
# training @ iter =  3000
# training @ iter =  3100
# epoch 14, learning_rate 0.100000 minibatch 225/225, validation error 29.460000 %
#      epoch 14, minibatch 225/225, test error of best model 31.520000 %
# training @ iter =  3200
# training @ iter =  3300
# epoch 15, learning_rate 0.100000 minibatch 225/225, validation error 29.220000 %
#      epoch 15, minibatch 225/225, test error of best model 31.200000 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 16, learning_rate 0.100000 minibatch 225/225, validation error 28.900000 %
#      epoch 16, minibatch 225/225, test error of best model 30.910000 %
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# epoch 17, learning_rate 0.100000 minibatch 225/225, validation error 28.640000 %
#      epoch 17, minibatch 225/225, test error of best model 30.560000 %
# training @ iter =  3900
# training @ iter =  4000
# epoch 18, learning_rate 0.100000 minibatch 225/225, validation error 28.720000 %
# training @ iter =  4100
# training @ iter =  4200
# epoch 19, learning_rate 0.090909 minibatch 225/225, validation error 28.140000 %
#      epoch 19, minibatch 225/225, test error of best model 30.140000 %
# training @ iter =  4300
# training @ iter =  4400
# epoch 20, learning_rate 0.090909 minibatch 225/225, validation error 27.940000 %
#      epoch 20, minibatch 225/225, test error of best model 30.220000 %
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# epoch 21, learning_rate 0.083333 minibatch 225/225, validation error 27.960000 %
# training @ iter =  4800
# training @ iter =  4900
# epoch 22, learning_rate 0.076923 minibatch 225/225, validation error 27.880000 %
#      epoch 22, minibatch 225/225, test error of best model 29.940000 %
# training @ iter =  5000
# training @ iter =  5100
# epoch 23, learning_rate 0.071429 minibatch 225/225, validation error 27.980000 %
# training @ iter =  5200
# training @ iter =  5300
# epoch 24, learning_rate 0.066667 minibatch 225/225, validation error 27.880000 %
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# epoch 25, learning_rate 0.062500 minibatch 225/225, validation error 27.720000 %
#      epoch 25, minibatch 225/225, test error of best model 29.760000 %
# training @ iter =  5700
# training @ iter =  5800
# epoch 26, learning_rate 0.058824 minibatch 225/225, validation error 28.060000 %
# training @ iter =  5900
# training @ iter =  6000
# epoch 27, learning_rate 0.055556 minibatch 225/225, validation error 27.780000 %
# training @ iter =  6100
# training @ iter =  6200
# epoch 28, learning_rate 0.052632 minibatch 225/225, validation error 27.820000 %
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# epoch 29, learning_rate 0.050000 minibatch 225/225, validation error 28.000000 %
# training @ iter =  6600
# training @ iter =  6700
# epoch 30, learning_rate 0.047619 minibatch 225/225, validation error 27.960000 %
# Optimization complete.
# Best validation score of 27.720000 % obtained at iteration 5625, with test performance 29.760000 %
# The training process for function test_renet ran for 17.53m

# %%
# more hidden layer of mlp
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'aug': False,
        'patch_size':4,
        'hidden_num':4,
        'hidden_unit':200,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 200
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: False
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 4
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 50.660000 %
#      epoch 1, minibatch 225/225, test error of best model 50.890000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 45.840000 %
#      epoch 2, minibatch 225/225, test error of best model 45.840000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 42.520000 %
#      epoch 3, minibatch 225/225, test error of best model 42.430000 %
# training @ iter =  700
# training @ iter =  800
# epoch 4, learning_rate 0.100000 minibatch 225/225, validation error 39.980000 %
#      epoch 4, minibatch 225/225, test error of best model 39.630000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# epoch 5, learning_rate 0.100000 minibatch 225/225, validation error 37.940000 %
#      epoch 5, minibatch 225/225, test error of best model 38.090000 %
# training @ iter =  1200
# training @ iter =  1300
# epoch 6, learning_rate 0.100000 minibatch 225/225, validation error 36.300000 %
#      epoch 6, minibatch 225/225, test error of best model 36.410000 %
# training @ iter =  1400
# training @ iter =  1500
# epoch 7, learning_rate 0.100000 minibatch 225/225, validation error 34.780000 %
#      epoch 7, minibatch 225/225, test error of best model 35.150000 %
# training @ iter =  1600
# training @ iter =  1700
# epoch 8, learning_rate 0.100000 minibatch 225/225, validation error 33.420000 %
#      epoch 8, minibatch 225/225, test error of best model 34.060000 %
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# epoch 9, learning_rate 0.100000 minibatch 225/225, validation error 32.360000 %
#      epoch 9, minibatch 225/225, test error of best model 33.120000 %
# training @ iter =  2100
# training @ iter =  2200
# epoch 10, learning_rate 0.100000 minibatch 225/225, validation error 32.100000 %
#      epoch 10, minibatch 225/225, test error of best model 32.720000 %
# training @ iter =  2300
# training @ iter =  2400
# epoch 11, learning_rate 0.100000 minibatch 225/225, validation error 31.860000 %
#      epoch 11, minibatch 225/225, test error of best model 32.230000 %
# training @ iter =  2500
# training @ iter =  2600
# epoch 12, learning_rate 0.100000 minibatch 225/225, validation error 31.940000 %
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# epoch 13, learning_rate 0.090909 minibatch 225/225, validation error 31.080000 %
#      epoch 13, minibatch 225/225, test error of best model 31.540000 %
# training @ iter =  3000
# training @ iter =  3100
# epoch 14, learning_rate 0.090909 minibatch 225/225, validation error 31.160000 %
# training @ iter =  3200
# training @ iter =  3300
# epoch 15, learning_rate 0.083333 minibatch 225/225, validation error 30.740000 %
#      epoch 15, minibatch 225/225, test error of best model 31.420000 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 16, learning_rate 0.083333 minibatch 225/225, validation error 31.040000 %
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# epoch 17, learning_rate 0.076923 minibatch 225/225, validation error 31.380000 %
# training @ iter =  3900
# training @ iter =  4000
# epoch 18, learning_rate 0.071429 minibatch 225/225, validation error 31.620000 %
# training @ iter =  4100
# training @ iter =  4200
# epoch 19, learning_rate 0.066667 minibatch 225/225, validation error 31.880000 %
# training @ iter =  4300
# training @ iter =  4400
# epoch 20, learning_rate 0.062500 minibatch 225/225, validation error 32.100000 %
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# epoch 21, learning_rate 0.058824 minibatch 225/225, validation error 32.060000 %
# training @ iter =  4800
# training @ iter =  4900
# epoch 22, learning_rate 0.055556 minibatch 225/225, validation error 31.800000 %
# training @ iter =  5000
# training @ iter =  5100
# epoch 23, learning_rate 0.052632 minibatch 225/225, validation error 32.340000 %
# training @ iter =  5200
# training @ iter =  5300
# epoch 24, learning_rate 0.050000 minibatch 225/225, validation error 32.560000 %
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# epoch 25, learning_rate 0.047619 minibatch 225/225, validation error 32.320000 %
# training @ iter =  5700
# training @ iter =  5800
# epoch 26, learning_rate 0.045455 minibatch 225/225, validation error 31.780000 %
# training @ iter =  5900
# training @ iter =  6000
# epoch 27, learning_rate 0.043478 minibatch 225/225, validation error 31.700000 %
# training @ iter =  6100
# training @ iter =  6200
# epoch 28, learning_rate 0.041667 minibatch 225/225, validation error 31.480000 %
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# epoch 29, learning_rate 0.040000 minibatch 225/225, validation error 31.480000 %
# training @ iter =  6600
# training @ iter =  6700
# epoch 30, learning_rate 0.038462 minibatch 225/225, validation error 31.440000 %
# Optimization complete.
# Best validation score of 30.740000 % obtained at iteration 3375, with test performance 31.420000 %
# The training process for function test_renet ran for 17.34m

# %%
#MLP
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'patch_size':4,
        'hidden_num':4,
        'hidden_unit':500,
        'renet_num':0,
        'adapt':False
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 500
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 0
# aug: True
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# adapt: False
# w: 32
# hidden_num: 4
# (45000, 3072)
# ... building the model
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 62.640000 %
#      epoch 1, minibatch 225/225, test error of best model 62.760000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 60.700000 %
#      epoch 2, minibatch 225/225, test error of best model 60.800000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 59.520000 %
#      epoch 3, minibatch 225/225, test error of best model 59.620000 %
# training @ iter =  700
# training @ iter =  800
# epoch 4, learning_rate 0.100000 minibatch 225/225, validation error 58.160000 %
#      epoch 4, minibatch 225/225, test error of best model 58.540000 %
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# epoch 5, learning_rate 0.100000 minibatch 225/225, validation error 57.040000 %
#      epoch 5, minibatch 225/225, test error of best model 57.330000 %
# training @ iter =  1200
# training @ iter =  1300
# epoch 6, learning_rate 0.100000 minibatch 225/225, validation error 55.400000 %
#      epoch 6, minibatch 225/225, test error of best model 55.760000 %
# training @ iter =  1400
# training @ iter =  1500
# epoch 7, learning_rate 0.100000 minibatch 225/225, validation error 53.960000 %
#      epoch 7, minibatch 225/225, test error of best model 54.170000 %
# training @ iter =  1600
# training @ iter =  1700
# epoch 8, learning_rate 0.100000 minibatch 225/225, validation error 53.080000 %
#      epoch 8, minibatch 225/225, test error of best model 53.220000 %
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# epoch 9, learning_rate 0.100000 minibatch 225/225, validation error 52.480000 %
#      epoch 9, minibatch 225/225, test error of best model 52.280000 %
# training @ iter =  2100
# training @ iter =  2200
# epoch 10, learning_rate 0.100000 minibatch 225/225, validation error 51.580000 %
#      epoch 10, minibatch 225/225, test error of best model 51.770000 %
# training @ iter =  2300
# training @ iter =  2400
# epoch 11, learning_rate 0.100000 minibatch 225/225, validation error 51.100000 %
#      epoch 11, minibatch 225/225, test error of best model 51.480000 %
# training @ iter =  2500
# training @ iter =  2600
# epoch 12, learning_rate 0.100000 minibatch 225/225, validation error 50.140000 %
#      epoch 12, minibatch 225/225, test error of best model 50.900000 %
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# epoch 13, learning_rate 0.100000 minibatch 225/225, validation error 49.580000 %
#      epoch 13, minibatch 225/225, test error of best model 50.630000 %
# training @ iter =  3000
# training @ iter =  3100
# epoch 14, learning_rate 0.100000 minibatch 225/225, validation error 49.720000 %
# training @ iter =  3200
# training @ iter =  3300
# epoch 15, learning_rate 0.100000 minibatch 225/225, validation error 49.160000 %
#      epoch 15, minibatch 225/225, test error of best model 49.970000 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 16, learning_rate 0.100000 minibatch 225/225, validation error 49.000000 %
#      epoch 16, minibatch 225/225, test error of best model 49.970000 %
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# epoch 17, learning_rate 0.100000 minibatch 225/225, validation error 48.980000 %
#      epoch 17, minibatch 225/225, test error of best model 50.070000 %
# training @ iter =  3900
# training @ iter =  4000
# epoch 18, learning_rate 0.100000 minibatch 225/225, validation error 49.000000 %
# training @ iter =  4100
# training @ iter =  4200
# epoch 19, learning_rate 0.100000 minibatch 225/225, validation error 49.120000 %
# training @ iter =  4300
# training @ iter =  4400
# epoch 20, learning_rate 0.100000 minibatch 225/225, validation error 49.540000 %
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# epoch 21, learning_rate 0.100000 minibatch 225/225, validation error 49.860000 %
# training @ iter =  4800
# training @ iter =  4900
# epoch 22, learning_rate 0.100000 minibatch 225/225, validation error 50.240000 %
# training @ iter =  5000
# training @ iter =  5100
# epoch 23, learning_rate 0.100000 minibatch 225/225, validation error 50.160000 %
# training @ iter =  5200
# training @ iter =  5300
# epoch 24, learning_rate 0.100000 minibatch 225/225, validation error 50.140000 %
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# epoch 25, learning_rate 0.100000 minibatch 225/225, validation error 50.340000 %
# training @ iter =  5700
# training @ iter =  5800
# epoch 26, learning_rate 0.100000 minibatch 225/225, validation error 51.440000 %
# training @ iter =  5900
# training @ iter =  6000
# epoch 27, learning_rate 0.100000 minibatch 225/225, validation error 51.020000 %
# training @ iter =  6100
# training @ iter =  6200
# epoch 28, learning_rate 0.100000 minibatch 225/225, validation error 53.040000 %
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# epoch 29, learning_rate 0.100000 minibatch 225/225, validation error 53.660000 %
# training @ iter =  6600
# training @ iter =  6700
# epoch 30, learning_rate 0.100000 minibatch 225/225, validation error 52.420000 %
# Optimization complete.
# Best validation score of 48.980000 % obtained at iteration 3825, with test performance 50.070000 %
# The training process for function test_renet ran for 0.60m
