# %%
from train import test_renet
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'renet_d':40,
        'w':28,
        'h':28,
        'c':1,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':250,
        'renet_num':1,
        "dataset":"mnist"
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 250
# verbose: True
# batch_size: 200
# dataset: mnist
# n_epochs: 30
# patch_size: 4
# c: 1
# renet_num: 1
# aug: True
# h: 28
# renet_d: 40
# ds_rate: 5
# lr: 0.1
# adapt: True
# w: 28
# hidden_num: 1
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 250/250, validation error 14.000000 %
#      epoch 1, minibatch 250/250, test error of best model 14.630000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 250/250, validation error 9.020000 %
#      epoch 2, minibatch 250/250, test error of best model 9.590000 %
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# ...
