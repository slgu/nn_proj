# %%
from train import test_renet
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
# With augmentation
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':500,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 500
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: True
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 61.780000 %
#      epoch 1, minibatch 225/225, test error of best model 60.840000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 57.560000 %
#      epoch 2, minibatch 225/225, test error of best model 57.150000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 54.820000 %
# ...

# %%
# Without augmentation
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'aug': False,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':500,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 500
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: False
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 61.320000 %
#      epoch 1, minibatch 225/225, test error of best model 60.920000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 56.980000 %
#      epoch 2, minibatch 225/225, test error of best model 56.710000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 54.140000 %
# ...

# %%
# less hidden state of renet
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':40,
        'w':32,
        'h':32,
        'c':3,
        'aug': False,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':500,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 500
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: False
# h: 32
# renet_d: 40
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 63.560000 %
#      epoch 1, minibatch 225/225, test error of best model 62.220000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 58.880000 %
#      epoch 2, minibatch 225/225, test error of best model 58.030000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 56.040000 %
# ...

# %%
# less hidden unit of mlp
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'aug': False,
        'patch_size':4,
        'hidden_num':1,
        'hidden_unit':200,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 200
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: False
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 1
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 61.980000 %
#      epoch 1, minibatch 225/225, test error of best model 61.290000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 56.880000 %
#      epoch 2, minibatch 225/225, test error of best model 56.540000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 53.840000 %
# ...

# %%
# more hidden layer of mlp
param = {
        'lr': 0.1,
        'verbose': True,
        'n_epochs':30,
        'batch_size':200,
        'ds_rate':5,
        'renet_d':80,
        'w':32,
        'h':32,
        'c':3,
        'aug': False,
        'patch_size':4,
        'hidden_num':4,
        'hidden_unit':200,
        'renet_num':1
}
test_renet(**param)
# Out:
# unit_option: gru
# hidden_unit: 200
# verbose: True
# batch_size: 200
# dataset: cifar
# n_epochs: 30
# patch_size: 4
# c: 3
# renet_num: 1
# aug: False
# h: 32
# renet_d: 80
# ds_rate: 5
# lr: 0.1
# w: 32
# hidden_num: 4
# (45000, 3072)
# ... building the model
# output done
# output done
# output done
# output done
# cost done
# test model done
# test valid model done
# update done
# train model done
# ... training
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# epoch 1, learning_rate 0.100000 minibatch 225/225, validation error 60.660000 %
#      epoch 1, minibatch 225/225, test error of best model 60.890000 %
# training @ iter =  300
# training @ iter =  400
# epoch 2, learning_rate 0.100000 minibatch 225/225, validation error 55.840000 %
#      epoch 2, minibatch 225/225, test error of best model 55.840000 %
# training @ iter =  500
# training @ iter =  600
# epoch 3, learning_rate 0.100000 minibatch 225/225, validation error 52.520000 %
# ...
